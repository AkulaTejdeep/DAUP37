# %% [markdown]
# <a href="https://colab.research.google.com/github/AkulaTejdeep/DAUP37/blob/main/2203A52133_DAUP_LAB_1_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/content/insurance.csv')

# %%
print("Dataset Preview:")
print(data.head())
# Out:
# Dataset Preview:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %% [markdown]
# VECTOR

# %%
# Vectors (Series in pandas)
age_vector = data['age'].values
print(age_vector)
# Out:
# [19 18 28 ... 18 21 61]

# %% [markdown]
# FACTORS

# %%
# Factors (categorical variables)
smoking_factor = data['smoker'].astype('category')
print(smoking_factor)
# Out:
# 0       yes
# 1        no
# 2        no
# 3        no
# 4        no
#        ...
# 1333     no
# 1334     no
# 1335     no
# 1336     no
# 1337    yes
# Name: smoker, Length: 1338, dtype: category
# Categories (2, object): ['no', 'yes']

# %% [markdown]
# LISTS

# %%
# Lists
age_list = data['age'].tolist()
print(age_list)
# Out:
# [19, 18, 28, 33, 32, 31, 46, 37, 37, 60, 25, 62, 23, 56, 27, 19, 52, 23, 56, 30, 60, 30, 18, 34, 37, 59, 63, 55, 23, 31, 22, 18, 19, 63, 28, 19, 62, 26, 35, 60, 24, 31, 41, 37, 38, 55, 18, 28, 60, 36, 18, 21, 48, 36, 40, 58, 58, 18, 53, 34, 43, 25, 64, 28, 20, 19, 61, 40, 40, 28, 27, 31, 53, 58, 44, 57, 29, 21, 22, 41, 31, 45, 22, 48, 37, 45, 57, 56, 46, 55, 21, 53, 59, 35, 64, 28, 54, 55, 56, 38, 41, 30, 18, 61, 34, 20, 19, 26, 29, 63, 54, 55, 37, 21, 52, 60, 58, 29, 49, 37, 44, 18, 20, 44, 47, 26, 19, 52, 32, 38, 59, 61, 53, 19, 20, 22, 19, 22, 54, 22, 34, 26, 34, 29, 30, 29, 46, 51, 53, 19, 35, 48, 32, 42, 40, 44, 48, 18, 30, 50, 42, 18, 54, 32, 37, 47, 20, 32, 19, 27, 63, 49, 18, 35, 24, 63, 38, 54, 46, 41, 58, 18, 22, 44, 44, 36, 26, 30, 41, 29, 61, 36, 25, 56, 18, 19, 39, 45, 51, 64, 19, 48, 60, 27, 46, 28, 59, 35, 63, 40, 20, 40, 24, 34, 45, 41, 53, 27, 26, 24, 34, 53, 32, 19, 42, 55, 28, 58, 41, 47, 42, 59, 19, 59, 39, 40, 18, 31, 19, 44, 23, 33, 55, 40, 63, 54, 60, 24, 19, 2
# ...

# %% [markdown]
# MATRIX

# %%
# Matrices
age_smoking_matrix = data[['age', 'smoker']].values
print(age_smoking_matrix)
# Out:
# [[19 'yes']
#  [18 'no']
#  [28 'no']
#  ...
#  [18 'no']
#  [21 'no']
#  [61 'yes']]

# %% [markdown]
# DATA FRAME

# %%
# Data frame
data.head()
# Out:
#    age     sex   bmi  children smoker     region  expenses
# 0   19  female  27.9         0    yes  southwest  16884.92
# 1   18    male  33.8         1     no  southeast   1725.55
# 2   28    male  33.0         3     no  southeast   4449.46
# 3   33    male  22.7         0     no  northwest  21984.47
# 4   32    male  28.9         0     no  northwest   3866.86

# %%
data_frame = data
print("Data Frame:")
print(data_frame)
# Out:
# Data Frame:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %% [markdown]
# b) Scatter plot with customizations

# %%
import matplotlib.pyplot as plt

# Scatter plot between age and smoking
plt.scatter(data['age'], data['smoker'], marker='x')
plt.title('Scatter Plot between Age and Smoking')
plt.xlabel('Age')
plt.ylabel('Smoking (yes/no)')
plt.text(30, 'yes','.', fontsize=12, ha='right')
plt.show()

# %%
x_column = data.columns[0]
y_column = data.columns[1]

plt.figure(figsize=(10, 6))
plt.scatter(data[x_column], data[y_column], c='red', marker='+', label='Data Points')
plt.title("Scatter Plot of {} vs {}".format(x_column, y_column))
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.legend()

# %% [markdown]
# c) Filter the data and update plot

# %%
# Scatter plot between age (20 to 40) and smoking
filtered_df = data[(data['age'] >= 20) & (data['age'] <= 40)]
plt.scatter(filtered_df['age'], filtered_df['smoker'], marker='+')
plt.title('Scatter Plot between Age (20 to 40) and Smoking')
plt.xlabel('Age')
plt.ylabel('Smoking')
plt.show()

# %% [markdown]
# d) Expenses of smokers and non-smokers

# %%
# Find expenses of smokers and non-smokers
smokers_expenses = data[data['smoker'] == 'yes']['expenses']
non_smokers_expenses = data[data['smoker'] == 'no']['expenses']

plt.boxplot([smokers_expenses, non_smokers_expenses], labels=['Smokers', 'Non-Smokers'])
plt.title('Expenses of Smokers vs Non-Smokers')
plt.ylabel('Expenses')
plt.show()
# Out:
# <ipython-input-38-06913be0db3f>:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([smokers_expenses, non_smokers_expenses], labels=['Smokers', 'Non-Smokers'])

# %%
x_column = data.columns[0]
y_column = data.columns[2]

plt.figure(figsize=(10, 6))
plt.scatter(data[x_column], data[y_column], c='green', marker='+', label='Data Points')
plt.title("Scatter Plot of {} vs {}".format(x_column, y_column))
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.legend()

for i in range(5):
    plt.text(data[x_column][i], data[y_column][i], str(i), fontsize=9)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Select numerical columns (excluding 'expenses')
numerical_cols = data.select_dtypes(include=['number']).columns.difference(['expenses'])

# Create scatter plots for each numerical column against 'expenses'
for col in numerical_cols:
    plt.figure(figsize=(8, 6))  # Adjust figure size as needed
    sns.scatterplot(x=col, y='expenses', data=data)
    plt.title(f'Scatter Plot: {col} vs. Expenses')
    plt.xlabel(col)
    plt.ylabel('Expenses')
    plt.show()

# %%
# Select categorical columns
categorical_cols = data.select_dtypes(include=['object']).columns

# Create bar plots or box plots for each categorical column against 'expenses'
for col in categorical_cols:
    plt.figure(figsize=(8, 6))  # Adjust figure size as needed
    # Choose either bar plot or box plot based on your preference
    # sns.barplot(x=col, y='expenses', data=df)  # For bar plot
    sns.boxplot(x=col, y='expenses', data=data)  # For box plot
    plt.title(f'{col.capitalize()} vs. Expenses')
    plt.xlabel(col.capitalize())
    plt.ylabel('Expenses')
    plt.show()

# %%
import pandas as pd

# Assuming your dataset is loaded into a pandas DataFrame called 'df'
# If not, replace 'df' with the actual name of your DataFrame
# df = pd.read_csv('your_dataset.csv')  # Replace 'your_dataset.csv' with the actual file path

# Group by 'sex' and calculate the sum of expenses for each group
gender_expenses = data.groupby('sex')['expenses'].sum()

# Print the results
print(gender_expenses)

# Determine which gender has more expenses
if gender_expenses['male'] > gender_expenses['female']:
    print("Males have more expenses.")
elif gender_expenses['female'] > gender_expenses['male']:
    print("Females have more expenses.")
else:
    print("Both genders have equal expenses.")
# Out:
# sex
# female    8321061.23
# male      9434763.96
# Name: expenses, dtype: float64
# Males have more expenses.

# %% [markdown]
# e) Number of smokers gender-wise

# %%
# Number of smokers gender-wise
smoker_gender_count = data[data['smoker'] == 'yes'].groupby('sex').size()

smoker_gender_count.plot(kind='bar',color = 'yellow')
plt.title('Number of Smokers by Gender')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# NUMBER OF TEENAGE SMOKERS

# %%
import pandas as pd

# Assuming your dataset is loaded into a pandas DataFrame called 'df'
# Replace 'your_dataset.csv' with the actual file path

# Filter for teenagers (age between 13 and 19) who are smokers
teenage_smokers = data[(data['age'] >= 13) & (data['age'] <= 19) & (data['smoker'] == 'yes')]

# Get the number of teenage smokers
num_teenage_smokers = len(teenage_smokers)

# Print the result
print("Number of teenage smokers:", num_teenage_smokers)
# Out:
# Number of teenage smokers: 30

# %%
threshold = data[x_column].mean()
filtered_data = data[data[x_column] > threshold]

plt.figure(figsize=(10, 6))
plt.scatter(filtered_data[x_column], filtered_data[y_column], c='blue', marker='o', label='Filtered Data')
plt.title("Filtered Scatter Plot of {} vs {}".format(x_column, y_column))
plt.xlabel(x_column)
plt.ylabel(y_column)
plt.legend()
